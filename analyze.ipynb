# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rewards_1a = "data/1a_1000_step_1000_rewards.npy"
rewards_1b = "data/1b_10000_step_10000_rewards.npy"
rewards_1c = "data/1c_200000_step_200000_rewards.npy"
rewards_2a = "data/2a_10000_step_10000_rewards.npy"

# %%
def moving_average(y, w):
  y_padded = np.pad(y, (w//2, w-1-w//2), mode='edge')
  return np.convolve(y_padded, np.ones((w,))/w, mode='valid') 

def plot_rewards(file, title):
  data = np.load(file)
  mov_avg = moving_average(data, 100)
  x = np.arange(0,len(data))
  plt.plot(x, data, label="return")
  plt.plot(x, mov_avg, label="moving average")

  plt.xlabel("episodes")
  plt.ylabel("R")
  plt.legend()
  plt.title(title)

# %%
plot_rewards(rewards_1a, "task 1a")

# %%
plot_rewards(rewards_1b, "task 1b")

# %%
plot_rewards(rewards_1c, "task 1c")
# Out:
# /home/kilian/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# **1 d)**

# %% [markdown]
# The problem with implementing q-learning for a board that big is that the q-table would become increadibly big as it has one entry for each possibility. In a 8x8 gameboard there are a lot more possibilities so only keeping that in RAM would be hard and also training it. For such cases deep q learning would be much more reasonable.

# %%
plot_rewards(rewards_2a, "task 2a")
